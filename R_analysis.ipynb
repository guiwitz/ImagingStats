# %%
analyzed_data = read.csv('BBBC013_analyzed.csv')

# %%
analyzed_data
# Out:
#    well.row well.column amount drug.type  area     intensity number.nuclei
# 1  A         1            0.00 Control    165.9877 22.00779  325
# 2  A         2            0.00 Control    171.3132 26.82912  265
# 3  A         3            0.98 Wortmannin 166.0980 34.06794  245
# 4  A         4            1.95 Wortmannin 165.5429 38.40321  210
# 5  A         5            3.91 Wortmannin 158.5494 41.63436  233
# 6  A         6            7.81 Wortmannin 165.7866 36.22001  239
# 7  A         7           15.63 Wortmannin 169.8038 53.86862  209
# 8  A         8           31.25 Wortmannin 183.3333 81.23068  195
# 9  A         9           62.50 Wortmannin 163.6439 70.41705  205
# 10 A        10          125.00 Wortmannin 138.3333 69.53536  192
# 11 A        11          250.00 Wortmannin 148.3413 62.61128  208
# 12 A        12          150.00 Control    143.8812 63.77603  202
# 13 B         1            0.00 Control    168.6048 27.01410  167
# ...

# %%
install.packages("ggplot2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/b2/k0ynj_5n4bd0qyqbg2tmj8g80000gp/T//RtmpHILERX/downloaded_packages

# %%
library(ggplot2)

# %%
ggplot(analyzed_data, aes(amount, intensity, colour = drug.type)) + 
  geom_point()+
  scale_x_continuous(trans='log10')
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous x-axis”
# plot without title
